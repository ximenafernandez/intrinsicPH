# %% [markdown]
# # Trefoil

# %%
from fermat_utils import *
from generate_data import *
from mpl_toolkits.mplot3d import Axes3D
from ripser import Rips

# %%
sample = np.loadtxt('trefoil_data.txt')
outliers = np.loadtxt('trefoil_out.txt')
data = np.concatenate((sample, outliers))

# %%
# data canalso be generated using the function trefoil()
#data = trefoil(1490, 'normal', 0.15, 123)
#n_out = 10
#X_out = (np.random.rand(n_out)-0.5)*5
#Y_out = (np.random.rand(n_out)-0.5)*5
#Z_out = (np.random.rand(n_out)-0.5)*5
#out = np.column_stack((X_out,Y_out,Z_out))

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(data[:,0], data[:,1],data[:,2], s=10, alpha = 0.3)
ax.scatter(X_out, Y_out,Z_out, s=10, alpha =1, color = 'red')
plt.savefig('trefoil.png',  bbox_inches='tight')
#ax.view_init(90,90)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(data[:,0], data[:,1],data[:,2], s=10, alpha = 0.3)
ax.scatter(X_out, Y_out, Z_out, s=10, alpha =1, color = 'red')
ax.zaxis.set_tick_params(labelsize=5)
ax.view_init(85,90)
plt.savefig('trefoil_arriba.png', bbox_inches='tight')

# %% [markdown]
# ## Persistence diagrams

# %% [markdown]
# ### Euclidean Distance

# %%
rips = Rips()
dgms = rips.fit_transform(data)
rips.plot(dgms, lifetime = True)
plt.title('Euclidean Distance')
plt.savefig('PH_trefoil_euclidean.png',  bbox_inches='tight')
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# ### Isomap distance

# %%
rips = Rips()
matrix = compute_adj_distance(data, 10)
dgms = rips.fit_transform(matrix, distance_matrix=True)
rips.plot(dgms, lifetime = True)
plt.title('Isomap distance k=10')
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# ### Fermat Distance

# %%
dgms = Fermat_dgm(data, p=3, rescaled = False)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
rips.plot([dgms[0][:0], dgms[1]], lifetime=True, title = 'Fermat Distance p=3 ($H_1$ only)')
plt.legend('')
plt.savefig('PH_trefoil_p=3_zoom.png',  bbox_inches='tight')

# %%
dgms = Fermat_dgm(data, p=4, rescaled = False)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
rips.plot([dgms[0][:0], dgms[1]], lifetime=True, title = 'Fermat Distance p=4 ($H_1$ only)')
plt.legend('')
